# %% [markdown]
# Data Understanding and checking data quality

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11828/434216820.py in <module>
#       2 import numpy as np
#       3 import seaborn as sns
# ----> 4 import missingno as msno
#       5 import matplotlib.pyplot as plt
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'missingno'

# %%
#Read csv file without ID column
ico_df = pd.read_csv("..\LUBS5990M_courseworkData_202223.csv",usecols=lambda x: x not in ["ID"])

# %%
#Getting an overview of data
ico_df.head()
# Out:
#   success                                        brandSlogan  hasVideo  \
# 0       N  Is One of Its Kind ERC-20 Decentralized Stable...         1
# 1       N            The Ultimate Blockchain Gaming Platform         1
# 2       N  Simple Automated Investment App Driven by AI & ML         1
# 3       Y    International Real Estate Crowdfunding Platform         1
# 4       N    Secure, Interference-Free Communications System         1
#
#    rating  priceUSD countryRegion   startDate     endDate  teamSize  \
# 0     4.0     30.00     Singapore  01/10/2019  01/10/2019      31.0
# 1     4.3      0.13         Malta  07/09/2018  12/10/2018      20.0
# 2     4.4      0.01            UK  01/07/2019  30/06/2020      10.0
# 3     4.3       NaN   Netherlands  01/10/2019  15/12/2019      27.0
# 4     4.3      0.03     Mauritius  28/07/2019  30/11/2019      14.0
#
#    hasGithub  hasReddit             platform     coinNum  minInvestment  \
# 0          1          1             Ethereum      509999              0
# 1          1          1                 XAYA   225000000              1
# 2          1          1              Stellar  5000000000              1
# 3          1          1  Separate blockchain   125000000              1
# 4          1          1             Ethereum  5000000000              1
#
#    distributedPercentage
# 0                   0.49
# 1                   0.41
# 2                   0.40
# 3                   0.13
# 4                   0.50

# %%
#Checking data types of each columns
ico_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2767 entries, 0 to 2766
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   success                2767 non-null   object
#  1   brandSlogan            2767 non-null   object
#  2   hasVideo               2767 non-null   category
#  3   rating                 2767 non-null   category
#  4   priceUSD               2587 non-null   float64
#  5   countryRegion          2696 non-null   object
#  6   startDate              2767 non-null   object
#  7   endDate                2767 non-null   object
#  8   teamSize               2613 non-null   float64
#  9   hasGithub              2767 non-null   category
#  10  hasReddit              2767 non-null   category
#  11  platform               2767 non-null   object
#  12  coinNum                2767 non-null   int64
#  13  minInvestment          2767 non-null   category
#  14  distributedPercentage  2767 non-null   float64
# dtypes: category(5), float64(3), int64(1), object(6)
# memory usage: 231.6+ KB

# %% [markdown]
# From the column description given in description file, we know that columns hasVideo, hasGithub, hasReddit, mininvestment, rating and success are category column.

# %%
#converting some columns to pandas category variable and displaying them
ico_df = ico_df.astype({'hasVideo':'category', 'hasGithub':'category','hasReddit':'category','minInvestment':'category','rating':'category','success':'category'})
ico_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2767 entries, 0 to 2766
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   success                2767 non-null   category
#  1   brandSlogan            2767 non-null   object
#  2   hasVideo               2767 non-null   category
#  3   rating                 2767 non-null   category
#  4   priceUSD               2587 non-null   float64
#  5   countryRegion          2696 non-null   object
#  6   startDate              2767 non-null   object
#  7   endDate                2767 non-null   object
#  8   teamSize               2613 non-null   float64
#  9   hasGithub              2767 non-null   category
#  10  hasReddit              2767 non-null   category
#  11  platform               2767 non-null   object
#  12  coinNum                2767 non-null   int64
#  13  minInvestment          2767 non-null   category
#  14  distributedPercentage  2767 non-null   float64
# dtypes: category(6), float64(3), int64(1), object(5)
# memory usage: 212.8+ KB

# %%
ico_df.isna().sum().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
msno.matrix(ico_df)
# Out:
# <Axes: >

# %%
msno.heatmap(ico_df)
# Out:
# <Axes: >

# %%
ico_df[ico_df['countryRegion'].isna()]
# Out:
#      success                                        brandSlogan hasVideo  \
# 611        N             AR Strategy With Blockchain Integrated        1
# 1232       N    Building the Next Level in Blockchain Solutions        1
# 1243       N                 Adrenaline AI IEO on ZBG Launchpad        1
# 1282       N  Save Up to 25% of the Price, Booking Hotels at...        0
# 1313       N    Create Truly Trusted Internet Content Ecosystem        0
# ...      ...                                                ...      ...
# 2735       N                          Decentralised marketplace        0
# 2741       N                               We Are Decentralized        0
# 2748       N            Fully Global Cryptocurrency Marketplace        0
# 2749       N                      The freedom that you deserve.        0
# 2757       N    Aspire to be the leading Crypto Investment Bank        0
#
#      rating  priceUSD countryRegion   startDate     endDate  teamSize  \
# 611     4.0      3.00           NaN  12/12/2018  12/01/2019      33.0
# 1232    3.2      0.49           NaN  01/09/2018  30/10/2018       8.0
# 1243    3.4      0.10           NaN  29/08/2019  29/08/2019      10.0
# 1282    3.0      1.00           NaN  01/07/2018  30/11/2018      14.0
# 1313    3.0      0.00           NaN  29/04/2019  29/04/2019      10.0
# ...     ...       ...           ...         ...         ...       ...
# 2735    1.6      0.78           NaN  01/11/2017  26/11/2017       NaN
# 2741    1.5       NaN           NaN  22/10/2017  22/11/2017       NaN
# 2748    1.1      0.45           NaN  08/11/2017  17/11/2017       NaN
# 2749    1.3      1.00           NaN  01/03/2018  31/05/2018       NaN
# 2757    1.1       NaN           NaN  26/11/2017  21/01/2018       NaN
#
#      hasGithub hasReddit  platform     coinNum minInvestment  \
# 611          1         1  Ethereum     7000000             0
# 1232         1         1  Ethereum    13125000             0
# 1243         0         0  Ethereum     9000000             1
# 1282         1         1  Ethereum     3500000             1
# 1313         0         0  Ethereum  2520000000             0
# ...        ...       ...       ...         ...           ...
# 2735         0         0  Ethereum    30000000             0
# 2741         0         0  Ethereum    50000000             0
# 2748         0         0  Ethereum    10500000             0
# 2749         0         0  Ethereum   300000000             0
# 2757         1         1  Ethereum    40000000             0
#
#       distributedPercentage
# 611                    0.35
# 1232                   0.63
# 1243                   0.02
# 1282                   0.64
# 1313                   0.28
# ...                     ...
# 2735                   1.00
# 2741                   0.32
# 2748                   0.70
# 2749                   0.60
# 2757                   0.25
#
# [71 rows x 15 columns]

# %% [markdown]
# Since there are only

# %%
ico_df.corr()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15280\2125472602.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ico_df.corr()
#                        priceUSD  teamSize   coinNum  distributedPercentage
# priceUSD               1.000000  0.008311 -0.000482              -0.000329
# teamSize               0.008311  1.000000 -0.012368              -0.021151
# coinNum               -0.000482 -0.012368  1.000000              -0.000611
# distributedPercentage -0.000329 -0.021151 -0.000611               1.000000

# %%
ico_df.describe()
# Out:
#            priceUSD     teamSize       coinNum  distributedPercentage
# count   2587.000000  2613.000000  2.767000e+03            2767.000000
# mean      19.014036    13.107539  8.177880e+12               1.061370
# std      775.287126     8.082433  4.300018e+14              17.485513
# min        0.000000     1.000000  1.200000e+01               0.000000
# 25%        0.040000     7.000000  5.000000e+07               0.400000
# 50%        0.120000    12.000000  1.800000e+08               0.550000
# 75%        0.500000    17.000000  6.000000e+08               0.700000
# max    39384.000000    75.000000  2.261908e+16             869.750000
